# %% [markdown]
# <a href="https://colab.research.google.com/github/navadeep2160/digit_prediction/blob/main/computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.datasets import mnist

# %%
(x_train,y_train), (x_test,y_test)=mnist.load_data()

# %%
x_train=x_train.reshape((60000, 784))
x_test=x_test.reshape((10000,784))

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=MLPClassifier(
    hidden_layer_sizes=(128,64),
    activation='relu',
    solver='adam',
    batch_size=128,
    max_iter=20


)

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(batch_size=128, hidden_layer_sizes=(128, 64), max_iter=20)

# %%
y_pred=model.predict(x_test)

# %%
print("Classification Report")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.98      0.97      0.98      1010
#            4       0.97      0.98      0.97       982
#            5       0.96      0.98      0.97       892
#            6       0.99      0.98      0.98       958
#            7       0.97      0.98      0.98      1028
#            8       0.99      0.95      0.97       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
plt.figure(figsize=(10,4))
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"Predicted: {y_pred[i]}")
    plt.axis('off')
plt.show()

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[ 971    0    1    1    1    1    2    2    0    1]
#  [   1 1126    4    0    0    0    2    0    2    0]
#  [   3    1 1014    5    2    0    1    4    2    0]
#  [   0    0    5  984    0    6    0    7    3    5]
#  [   1    0    3    1  960    1    3    2    0   11]
#  [   2    0    0    4    3  877    3    1    0    2]
#  [   3    2    1    1    3   10  937    1    0    0]
#  [   0    2    5    3    1    0    0 1009    2    6]
#  [   3    2    3    7    6   11    2    5  926    9]
#  [   3    2    0    1   12    3    1    4    0  983]]
